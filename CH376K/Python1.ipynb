# %% [markdown]
# # Welcome to Python!
#
# Python is a very powerful yet easy to use programming language that has become one of the most commonly used languages, especially in science. There are a variety of ways to use Python. You can run Python in a command line structure and type out commands. You can also write scripts and then run the whole script at once. Here, we are going to use a Python notebook using a program called Jupyter.
#
# Some cells, like this, are text only (in a format called Markdown). I'll use these to type out things to know. Other cells are executable blocks of code. You can run them in different orders and rerun bits of code, but the results of the output will live in the memory, as you will see later. Throughout these assignments, you'll encounter text like this, example code, and problems that you need to complete.
#
# ### Important Tips
#
# * **Read everything from the start.** Students that just jump to the problem and try to race through it tend to struggle. If you read through the material, you'll learn a lot about how it works.
# * Relately, **it is important to actually do the work.** If you just plug it into AI or copy from a friend, it may work, but you won't learn anything. Then, when it doesn't work, you won't know what to do.
#
# # Part 1: Programming Basics
#
# First, we will show how to print some basic text. We do this with the print() command. Strings, which are character text and not computable numbers, are always in either single or double quotes.
#
# ## Problem 0:
#
# First, replace the ... in the print command below with your name, and hit Shift + Enter to execute.

# %%
print("Hello World! My name is ...")
# Out:
# Hello World! My name is ...

# %% [markdown]
# When you execute the code block, it will print out the result below. It will only print things that you tell it to print or show plots that you tell it to show. It's very helpful when debugging to print stuff out, but clean it up after so that only the important stuff is printed.
#
# ## Variables, Lists, and Arrays
#
# This block of code shows you how to define variables. Variables are simply some sort of data stored in as a particular name. Variables can be strings, floats, lists, arrays, or classes. Once you store these, you can recall them later.
#
# Run this block of code by clicking run or Shift + Enter or Ctrl + Enter.

# %%
a=1
b=2
c=a+b
print("c = ", c)
# Hit shift + enter to see the result: c = 3
# Out:
# c =  3

# %% [markdown]
# Here, **a** is stored as the number 1, and **b** is stored as the number 2. We can save **c** as the sum of **a** and **b**. The print() command prints various things. Using quotes tells program to consider what is inside as text (a string) rather than a variable.
#
# Using a # sign at the beginning of the line tells the program that this is just a comment, not actual code, and it will ignore it.
#
# As the comment says, hitting Shift + Enter will run the block of code.
#
# Other common mathematical operations are performed using -, *, and /. Powers are done with **, not ^.
#
# ## Problem 1:
# Use the next code block to define d as the product of a and b and print the result. Note, you don't need to define a and b again.

# %%
# Your work here...

# %% [markdown]
# Python is good at calculating single variables, but the main advantage is that is can work with a lot of data at once, which is difficult to do by calculator or even Excel.
#
# A **list** in Python is simply a collection of things, which can be variables, numbers, or string.
#
# An **array** is like a list but is more useful because operations can be performed on the whole array.
#
# To use array, we need to import a library called Numerical Python or NumPy. After you import it by running this block of code, you don't need to reimport it again while you are still running the program. However, you will need to reimport it every time you start Python.
#
# **Tip:** If you get errors with numpy not loading, you may need to install it on your computer. This is relatively easy to do with "pip install numpy" if you have set up Python to be in your system path. Also, if you close the notebook and reopen it, you will need to reimport these libraries by running this code block again. It can be confusing to have all the code running in small chunks. One way to help with that is to click "Run > Run All Above Selected Cell" from the menu above. This will quickly run everything above and make sure the imports are done.
#
# This example will show you how to build an array and use it to do mathematical operations.

# %%
import numpy as np

x = np.array([1,2,3,4,5,6])
y = x ** 2
print(y)
# Out:
# [ 1  4  9 16 25 36]

# %% [markdown]
# You can see we built an array using the command np.array() with 1 through 6 in it. We used the ** operation to square the values in the array.
#
# We have imported numpy as np, so we can use numpy functions by calling "np.function_name". We will learn a handful of numpy functions throughout this tutorial.
#
# Now, let's learn how to plot this data. For this, we need to import another library, MatPlotLib, and we are going to use the pyplot submodule of it. We will rename this as plt to make it easy to access.

# %%
import matplotlib.pyplot as plt

plt.plot(x,y)
plt.show()

# %% [markdown]
# Note, if this plot doesn't work, make sure you ran the input above to define x and y. Otherwise, it won't know what to plot.
#
# You can see that we generated a plot of x versus y, which should have a classic parabola form. We need to include the show() command to make it print out the plot.
#
# Plotting the results is a really useful way to see what your data looks like and debug things.
#
# ## Problem 2:
# Create a plot of an array of x**2 + 5 from -4 to 4.

# %%
# Your code here

# %% [markdown]
# ## Gaussians and Functions
#
# Often, you want to write functions to simplify things. This is done using **def**, defining the function **name** and **(inputs)**, and using **return** to specify the outputs.
#
# Note you need a **colon** after the function definition and **everything inside the function needs to be tabbed.** The first untabbed line will exit the function. If you don't include a return, the function will return **None**.
#
# This function simply defines add and returns the sum of two numbers. You call it using add() and inserting the two numbers.

# %%
def add(a, b):
    c = a+b
    return c

print("The sum is:", add(4,5))
# Out:
# The sum is: 9

# %% [markdown]
# This function defines a Gaussian Distribution (equation 4.3 in the textbook). It makes use of a few new numpy functions: **np.sqrt()** (Square Root), **np.exp()** (Exponential or e^x), and **np.pi** (simply the constant Pi).
#
# We then define x using another numpy function, **np.arange()**, which creates an array of values ranging from the minimum to the maximum in increments of 1, which is the default.
#
# If any of these functions are confusing, add in a print command to see what the outputs look like.
#
# We can define y and z as the outputs of the Gaussian function with different inputs.

# %%
def Gaussian(xvalues, mean, standard_deviation):
    sdsquared = standard_deviation**2
    exponent = -(xvalues - mean)**2/(2 * sdsquared)
    preexponential = 1 / np.sqrt(2 * np.pi * sdsquared)
    return preexponential * np.exp(exponent)

x = np.arange(-10, 10, 0.1)
y = Gaussian(x, 0, 3)
z = Gaussian(x, 0, 1)

plt.plot(x, y)
plt.plot(x, z)
plt.show()

# %% [markdown]
# Gaussian Distributions are defined by two parameters: the mean and the standard deviation. The mean specifies where the center of the distribution is. The standard deviation specifies the width of the peak.
#
# The above block of code also shows you how to plot multiple things on the same graph by just adding extra plot commands before you call show().
#
# This plot shows an example of two Gaussian distributions with the same mean but different standard deviations. Notice, the area under both curves should be 1, which is why the peak intensities are different.
#
# ## Problem 3:
# 1) Plot two Gaussian distributions with a standard deviation of 2 and means of 5 and 10, respectively.
# 2) Plot the sum of the two distributions, which is done by simply adding the arrays (y+z). Overlay this line on the other two distributions in a single plot for all three.
#
# **Tip:** you will want to extend the x values to hit the whole range.

# %%
# Your work here...

# %% [markdown]
# ## Mean and Standard Deviation
#
# A lot of analytical data take the form of a Gaussian, so it is important that we can calculate the mean and standard deviation of data.
#
# Mean = Sum of X / number of data points in X
#
# Let's calculate the mean using a few programmatic tricks. Here, np.sum() allows us to quickly sum the array and len() lets us calculate how long the array is (the number of data points).
#
# Numpy (of course) has built in functions to calculate mean with np.mean() or np.average().

# %%
x = np.arange(0, 7) #[0,1,2,3,4,5,6]

mean = np.sum(x)/len(x)
print("Our mean calculation:", mean)

mean2 = np.mean(x)
print("Numpy mean:", mean2)

mean3 = np.average(x)
print("Numpy average:", mean3)
# Out:
# Our mean calculation: 3.0
# Numpy mean: 3.0
# Numpy average: 3.0

# %% [markdown]
# These should all give the same output: 3. Make sure you also understand how to do that by hand and compare with equation 4-1 in the textbook.
#
# The standard deviation is calculated as shown below. Write this out or compare it with equation 4-2 in the textbook to make sure you understand it.

# %%
std_dev = np.sqrt(np.sum((x - mean)**2)/(len(x)-1))
print("Our std dev calculation:", std_dev)
# Out:
# Our std dev calculation: 2.160246899469287

# %% [markdown]
# Numpy also has a function for standard deviation. Here, we need to remember to add a delta degree of freedom (ddof) of 1 to account for the fact that we've calculated the mean.

# %%
std_dev_numpy = np.std(x, ddof=1)
print("Numpy std dev:", std_dev_numpy)
# Out:
# Numpy std dev: 2.160246899469287

# %% [markdown]
# ## Problem 4:
# 1) Write a function to calculate the standard deviation from only one array input, x.
# 2) Using the provided x array, compare the printout of your function with the numpy function to calculate standard deviation, np.std().
#
# You can use any function you want in your function except np.std(). To clarify, I want to write your own function here using def and the same method outlined above with add() and Gaussian(). It should take only one input. I've given you the start.

# %%
x = np.array([4,7,2,6,8,4,2,5,6,7,8,4,2])

def StandardDeviation(x):
    #Your code here. 
    pass

# %% [markdown]
#
#  Ok, now that you have written a function to calculate standard deviation. Let's use it on some mock analytical data.
#
# I've added some code to generate some random data, imagine these being from any analytical measurement. The function np.random.normal lets us generate random data with a mean and standard deviation as defined in the code.
#
# The function plt.hlines() allows us to put a horizontal line on the plot at a specific y value (mean) ranging from a minmum x value (0) to a maximum x value (number). The rest of the code are some parameters for color and line style. These can also be used with the normal plot() command.
#
# ## Problem 5:
# This code shows the **theoretical** mean and standard deviation.
#
# Use any of the code above to:
# 1) Calculate the **experimental** mean for the random "areas" in the code below
# 2) Calculate the **experimental** standard deviation for the random "areas".
# 3) Print out 1 and 2.
# 4) Add the **experimental** mean and std deviation ranges as black lines to the plot alongside the red theoretical lines.
# 5) Change the number of data points to either much smaller or much larger. Look at how do the experimental and theoretical means compare with different sizes of total numbers of measurements.

# %%
mean = 725
std_dev = 50
number = 10
areas = np.random.normal(mean, std_dev, number)

#Your code here...

plt.plot(areas, marker="o", linestyle="")
plt.hlines(mean, 0, number, color="red", label="Theoretical Mean")
plt.hlines(mean + std_dev, 0, number, color="red", linestyle="--", label="Theroetical Std Dev")
plt.hlines(mean - std_dev, 0, number, color="red", linestyle="--")

#Your code here...

plt.ylabel("Peak Area")
plt.xlabel("Measurement Number")
plt.legend()
plt.show()

# %% [markdown]
# This gives you an example of what might happen in a real set of measurements. This also shows you why Python is so powerful. You can quickly process a lot of data, do a range of manipulations, and generate really nice plots afterwards.
#
# The code below shows a histogram of the a data points compared with the true underlying statistical Gaussian distribution.

# %%
x = np.arange(mean - 4 * std_dev, mean + 4 * std_dev , 1)
y = Gaussian(x, mean, std_dev)

plt.hist(areas, density=True)
plt.plot(x, y)
plt.xlabel("Peak Area")
plt.ylabel("Normalized Counts")
plt.show()

# %% [markdown]
# # Part 2: Linear regression.
# Another common thing analytical chemists need to do is generate a calibration curve.
#
# We will start by simulating a linear response of peak areas with a known input concentration. We will add in some noise using the same function above.
#
# We are using the xlabel() and ylabel() functions to write the axes labels.

# %%
slope = 59.16
intercept = 0.5

x = np.arange(0,20)
y = slope * x + intercept
noise = np.random.normal(0, 50, len(x))
y = y + noise

plt.plot(x, y)
plt.xlabel("Concentration")
plt.ylabel("Peak Area")
plt.show()

# %% [markdown]
# Now, imagine we didn't know the slope and the intercept. We need to calculate this from the x and y data.
#
# To do this, we will use numpy's polyfit command. It can fit any order polynomial, but here we will use an order of 1 to get a linear fit. It returns an array (fit) of the polynomial coefficients in decending order. Thus, the slope is the first value in the array, and the intercept is the second value. These should be close to the values above. If you were to remove the noise (for example by commenting out the line that added it in or by reducing the standard deviation of the noise to 0), you should have values that perfectly match the inputs.
#
# To access individual values from an array, we use []. In computer programming, the first value is actually position 0. So, fit[0] gives you the slope or first element of array. Using fit[1] will extract the second value of the array.

# %%
fit = np.polyfit(x,y, 1)
print("Fit:", fit)

fit_intercept = fit[1]
fit_slope = fit[0]

print(f"Slope: {fit_slope} and Intercept: {fit_intercept}")

fit_ydata = fit_slope * x + fit_intercept

plt.plot(x, y, marker="o")
plt.plot(x, fit_ydata, color="red")
plt.xlabel("Concentration")
plt.ylabel("Peak Area")
plt.show()
# Out:
# Fit: [59.08522236 -4.80144635]
# Slope: 59.08522235791539 and Intercept: -4.801446352282868

# %% [markdown]
# ## Problem 6:
# 1) Write a function to calculate the concentration (x value) from a measured peak area (y value) based on the calibration parameters you determined. Do not type these values in, but use them as variables from the calculations above.
# 2) Solve for a measured peak area of 725 and print the result.
# 3) Plot the measured value on the same plot above using a green dot.
# 4) Calculate the uncertainty from equation 4-27 in the textbook and print the result. If you are feeling brave, add an error bar to your green point to show the uncertainty.

# %%
# Your code here

# %% [markdown]
# # Turning in the Assignment
#
# Congratulations on finishing your first Python notebook!
#
# Now, please print a PDF of this an upload it to the assignment folder. The best way to do this is to click File > Save and Export Notebook As > HTML. Then, open the HTML and print it as a PDF from your browser. There are other ways to export it, but that is the most reliable.
#
# Note, it is important that you upload the PDF file. **We will not grade an HTML or ipynb file.**
#
# It is also important that you **executed every cell**. If you have opened and closed the file multiple times, it may not have retained the outputs from earlier. Go back to check that each printout and plot are shown correctly. If you need to, you can select "Run All Cells" to make sure everything runs from top to bottom. Avoid any circular code loops where code from below is needed for code above.
#
# Alternatively, it is possible to directly export to a pdf if you install pandoc ahead of time: https://pandoc.org/installing.html. You will need to restart Jupyter after installing. After doing this, you can use the same Export Notebook As to export to PDF.
